# %%
#%matplotlib notebook
import uproot as ur
import matplotlib.pyplot as plt
import k3d
import numpy as np
import awkward as ak
from pyjet import cluster
from pyjet.testdata import get_event
from pyjet import DTYPE_EP
from pyjet import DTYPE_PTEPM
from pyjet import PseudoJet, JetDefinition, ClusterSequence, ClusterSequenceArea
import pandas as pd

# %% [markdown]
# ## Get data, transform ROOT tree into array

# %%
file = ur.open('rec_highq2.root')
tree = file['events']
ak_arrays = tree.arrays()

gen_file = ur.open('sim_highq2.root')
gen_tree = gen_file['events']
gen_ak_arrays = gen_tree.arrays()

gen_tree.keys()
# Out:
# ['mcparticles',
#  'mcparticles/mcparticles.ID',
#  'mcparticles/mcparticles.g4Parent',
#  'mcparticles/mcparticles.reason',
#  'mcparticles/mcparticles.mask',
#  'mcparticles/mcparticles.steps',
#  'mcparticles/mcparticles.secondaries',
#  'mcparticles/mcparticles.pdgID',
#  'mcparticles/mcparticles.status',
#  'mcparticles/mcparticles.colorFlow[2]',
#  'mcparticles/mcparticles.genStatus',
#  'mcparticles/mcparticles.charge',
#  'mcparticles/mcparticles.spare[1]',
#  'mcparticles/mcparticles.spin[3]',
#  'mcparticles/mcparticles.vsx',
#  'mcparticles/mcparticles.vsy',
#  'mcparticles/mcparticles.vsz',
#  'mcparticles/mcparticles.vex',
#  'mcparticles/mcparticles.vey',
#  'mcparticles/mcparticles.vez',
#  'mcparticles/mcparticles.psx',
#  'mcparticles/mcparticles.psy',
#  'mcparticles/mcparticles.psz',
#  'mcparticles/mcparticles.pex',
#  'mcparticles/mcparticles.pey',
#  'mcparticles/mcparticles.pez',
#  'mcparticles/mcparticles.mass',
#  'mcparticles/mcparticles.time',
#  'mcparticles/mcparticles.properTime',
#  'mcparticles/mcparticles.parents_begin',
#  'mcparticles/mcparticles.parents_end',
#  'mcparticles/mcparticles.daughters_begin',
#  'mcparticles/mcparticles.daughters_end',
#  'mcparticles_0',
#  'mcparticles_1',
#  'TrackerBarrelHits',
#  'TrackerBarrelHits/TrackerBarrelHits.cellID',
#  'TrackerBarrelHits/TrackerBarrelHits.flag',
#  'TrackerBarrelHits/TrackerBarrelHits.g4ID',
#  'TrackerBarrelHits/TrackerBarrelHits.position.x',
#  'TrackerBarrelHits/TrackerBarrelHits.position.y',
#  'TrackerBarrelHits/TrackerBarrelHits.position.z',
#  'TrackerBarrelHits/TrackerBarrelHits.position.t',
#  'TrackerBarrelHits/TrackerBarrelHits.momentum.x',
#  'TrackerBarrelHits/TrackerBarrelHits.momentum.y',
#  'TrackerBarrelHits/TrackerBarrelHits.momentum.z',
#  'TrackerBarrelHits/TrackerBarrelHits.momentum.t',
#  'TrackerBarrelHits/TrackerBarrelHits.length',
#  'TrackerBarrelHits/TrackerBarrelHits.truth.trackID',
#  'TrackerBarrelHits/TrackerBarrelHits.truth.pdgID',
#  'TrackerBarrelHits/TrackerBarrelHits.truth.deposit',
#  'TrackerBarrelHits/TrackerBarrelHits.truth.time',
#  'TrackerBarrelHits/TrackerBarrelHits.truth.length',
#  'TrackerBarrelHits/TrackerBarrelHits.truth.x',
#  'TrackerBarrelHits/TrackerBarrelHits.truth.y',
#  'TrackerBarrelHits/TrackerBarrelHits.truth.z',
#  'TrackerBarrelHits/TrackerBarrelHits.energyDeposit',
#  'DIRCHits',
#  'DIRCHits/DIRCHits.cellID',
#  'DIRCHits/DIRCHits.flag',
#  'DIRCHits/DIRCHits.g4ID',
#  'DIRCHits/DIRCHits.position.x',
#  'DIRCHits/DIRCHits.position.y',
#  'DIRCHits/DIRCHits.position.z',
#  'DIRCHits/DIRCHits.position.t',
#  'DIRCHits/DIRCHits.momentum.x',
#  'DIRCHits/DIRCHits.momentum.y',
#  'DIRCHits/DIRCHits.momentum.z',
#  'DIRCHits/DIRCHits.momentum.t',
#  'DIRCHits/DIRCHits.length',
#  'DIRCHits/DIRCHits.truth.trackID',
#  'DIRCHits/DIRCHits.truth.pdgID',
#  'DIRCHits/DIRCHits.truth.deposit',
#  'DIRCHits/DIRCHits.truth.time',
#  'DIRCHits/DIRCHits.truth.length',
#  'DIRCHits/DIRCHits.truth.x',
#  'DIRCHits/DIRCHits.truth.y',
#  'DIRCHits/DIRCHits.truth.z',
#  'DIRCHits/DIRCHits.energy',
#  'MRICHHits',
#  'MRICHHits/MRICHHits.cellID',
#  'MRICHHits/MRICHHits.flag',
#  'MRICHHits/MRICHHits.g4ID',
#  'MRICHHits/MRICHHits.position.x',
#  'MRICHHits/MRICHHits.position.y',
#  'MRICHHits/MRICHHits.position.z',
#  'MRICHHits/MRICHHits.position.t',
#  'MRICHHits/MRICHHits.momentum.x',
#  'MRICHHits/MRICHHits.momentum.y',
#  'MRICHHits/MRICHHits.momentum.z',
#  'MRICHHits/MRICHHits.momentum.t',
#  'MRICHHits/MRICHHits.length',
#  'MRICHHits/MRICHHits.truth.trackID',
#  'MRICHHits/MRICHHits.truth.pdgID',
#  'MRICHHits/MRICHHits.truth.deposit',
#  'MRICHHits/MRICHHits.truth.time',
#  'MRICHHits/MRICHHits.truth.length',
#  'MRICHHits/MRICHHits.truth.x',
#  'MRICHHits/MRICHHits.truth.y',
#  'MRICHHits/MRICHHits.truth.z',
#  'MRICHHits/MRICHHits.energy',
#  'HcalBarrelHits',
#  'HcalBarrelHits/HcalBarrelHits.cellID',
#  'HcalBarrelHits/HcalBarrelHits.flag',
#  'HcalBarrelHits/HcalBarrelHits.g4ID',
#  'HcalBarrelHits/HcalBarrelHits.position.x',
#  'HcalBarrelHits/HcalBarrelHits.position.y',
#  'HcalBarrelHits/HcalBarrelHits.position.z',
#  'HcalBarrelHits/HcalBarrelHits.position.t',
#  'HcalBarrelHits/HcalBarrelHits.truth.trackID',
#  'HcalBarrelHits/HcalBarrelHits.truth.pdgID',
#  'HcalBarrelHits/HcalBarrelHits.truth.deposit',
#  'HcalBarrelHits/HcalBarrelHits.truth.time',
#  'HcalBarrelHits/HcalBarrelHits.truth.length',
#  'HcalBarrelHits/HcalBarrelHits.truth.x',
#  'HcalBarrelHits/HcalBarrelHits.truth.y',
#  'HcalBarrelHits/HcalBarrelHits.truth.z',
#  'HcalBarrelHits/HcalBarrelHits.energyDeposit',
#  'VertexBarrelHits',
#  'VertexBarrelHits/VertexBarrelHits.cellID',
#  'VertexBarrelHits/VertexBarrelHits.flag',
#  'VertexBarrelHits/VertexBarrelHits.g4ID',
#  'VertexBarrelHits/VertexBarrelHits.position.x',
#  'VertexBarrelHits/VertexBarrelHits.position.y',
#  'VertexBarrelHits/VertexBarrelHits.position.z',
#  'VertexBarrelHits/VertexBarrelHits.position.t',
#  'VertexBarrelHits/VertexBarrelHits.momentum.x',
#  'VertexBarrelHits/VertexBarrelHits.momentum.y',
#  'VertexBarrelHits/VertexBarrelHits.momentum.z',
#  'VertexBarrelHits/VertexBarrelHits.momentum.t',
#  'VertexBarrelHits/VertexBarrelHits.length',
#  'VertexBarrelHits/VertexBarrelHits.truth.trackID',
#  'VertexBarrelHits/VertexBarrelHits.truth.pdgID',
#  'VertexBarrelHits/VertexBarrelHits.truth.deposit',
#  'VertexBarrelHits/VertexBarrelHits.truth.time',
#  'VertexBarrelHits/VertexBarrelHits.truth.length',
#  'VertexBarrelHits/VertexBarrelHits.truth.x',
#  'VertexBarrelHits/VertexBarrelHits.truth.y',
#  'VertexBarrelHits/VertexBarrelHits.truth.z',
#  'VertexBarrelHits/VertexBarrelHits.energyDeposit',
#  'VertexEndcapHits',
#  'VertexEndcapHits/VertexEndcapHits.cellID',
#  'VertexEndcapHits/VertexEndcapHits.flag',
#  'VertexEndcapHits/VertexEndcapHits.g4ID',
#  'VertexEndcapHits/VertexEndcapHits.position.x',
#  'VertexEndcapHits/VertexEndcapHits.position.y',
#  'VertexEndcapHits/VertexEndcapHits.position.z',
#  'VertexEndcapHits/VertexEndcapHits.position.t',
#  'VertexEndcapHits/VertexEndcapHits.momentum.x',
#  'VertexEndcapHits/VertexEndcapHits.momentum.y',
#  'VertexEndcapHits/VertexEndcapHits.momentum.z',
#  'VertexEndcapHits/VertexEndcapHits.momentum.t',
#  'VertexEndcapHits/VertexEndcapHits.length',
#  'VertexEndcapHits/VertexEndcapHits.truth.trackID',
#  'VertexEndcapHits/VertexEndcapHits.truth.pdgID',
#  'VertexEndcapHits/VertexEndcapHits.truth.deposit',
#  'VertexEndcapHits/VertexEndcapHits.truth.time',
#  'VertexEndcapHits/VertexEndcapHits.truth.length',
#  'VertexEndcapHits/VertexEndcapHits.truth.x',
#  'VertexEndcapHits/VertexEndcapHits.truth.y',
#  'VertexEndcapHits/VertexEndcapHits.truth.z',
#  'VertexEndcapHits/VertexEndcapHits.energyDeposit',
#  'EcalEndcapPHits',
#  'EcalEndcapPHits/EcalEndcapPHits.cellID',
#  'EcalEndcapPHits/EcalEndcapPHits.flag',
#  'EcalEndcapPHits/EcalEndcapPHits.g4ID',
#  'EcalEndcapPHits/EcalEndcapPHits.position.x',
#  'EcalEndcapPHits/EcalEndcapPHits.position.y',
#  'EcalEndcapPHits/EcalEndcapPHits.position.z',
#  'EcalEndcapPHits/EcalEndcapPHits.position.t',
#  'EcalEndcapPHits/EcalEndcapPHits.truth.trackID',
#  'EcalEndcapPHits/EcalEndcapPHits.truth.pdgID',
#  'EcalEndcapPHits/EcalEndcapPHits.truth.deposit',
#  'EcalEndcapPHits/EcalEndcapPHits.truth.time',
#  'EcalEndcapPHits/EcalEndcapPHits.truth.length',
#  'EcalEndcapPHits/EcalEndcapPHits.truth.x',
#  'EcalEndcapPHits/EcalEndcapPHits.truth.y',
#  'EcalEndcapPHits/EcalEndcapPHits.truth.z',
#  'EcalEndcapPHits/EcalEndcapPHits.energyDeposit',
#  'TrackerEndcapHits',
#  'TrackerEndcapHits/TrackerEndcapHits.cellID',
#  'TrackerEndcapHits/TrackerEndcapHits.flag',
#  'TrackerEndcapHits/TrackerEndcapHits.g4ID',
#  'TrackerEndcapHits/TrackerEndcapHits.position.x',
#  'TrackerEndcapHits/TrackerEndcapHits.position.y',
#  'TrackerEndcapHits/TrackerEndcapHits.position.z',
#  'TrackerEndcapHits/TrackerEndcapHits.position.t',
#  'TrackerEndcapHits/TrackerEndcapHits.momentum.x',
#  'TrackerEndcapHits/TrackerEndcapHits.momentum.y',
#  'TrackerEndcapHits/TrackerEndcapHits.momentum.z',
#  'TrackerEndcapHits/TrackerEndcapHits.momentum.t',
#  'TrackerEndcapHits/TrackerEndcapHits.length',
#  'TrackerEndcapHits/TrackerEndcapHits.truth.trackID',
#  'TrackerEndcapHits/TrackerEndcapHits.truth.pdgID',
#  'TrackerEndcapHits/TrackerEndcapHits.truth.deposit',
#  'TrackerEndcapHits/TrackerEndcapHits.truth.time',
#  'TrackerEndcapHits/TrackerEndcapHits.truth.length',
#  'TrackerEndcapHits/TrackerEndcapHits.truth.x',
#  'TrackerEndcapHits/TrackerEndcapHits.truth.y',
#  'TrackerEndcapHits/TrackerEndcapHits.truth.z',
#  'TrackerEndcapHits/TrackerEndcapHits.energyDeposit',
#  'EcalBarrelHits',
#  'EcalBarrelHits/EcalBarrelHits.cellID',
#  'EcalBarrelHits/EcalBarrelHits.flag',
#  'EcalBarrelHits/EcalBarrelHits.g4ID',
#  'EcalBarrelHits/EcalBarrelHits.position.x',
#  'EcalBarrelHits/EcalBarrelHits.position.y',
#  'EcalBarrelHits/EcalBarrelHits.position.z',
#  'EcalBarrelHits/EcalBarrelHits.position.t',
#  'EcalBarrelHits/EcalBarrelHits.truth.trackID',
#  'EcalBarrelHits/EcalBarrelHits.truth.pdgID',
#  'EcalBarrelHits/EcalBarrelHits.truth.deposit',
#  'EcalBarrelHits/EcalBarrelHits.truth.time',
#  'EcalBarrelHits/EcalBarrelHits.truth.length',
#  'EcalBarrelHits/EcalBarrelHits.truth.x',
#  'EcalBarrelHits/EcalBarrelHits.truth.y',
#  'EcalBarrelHits/EcalBarrelHits.truth.z',
#  'EcalBarrelHits/EcalBarrelHits.energyDeposit',
#  'EcalEndcapNHits',
#  'EcalEndcapNHits/EcalEndcapNHits.cellID',
#  'EcalEndcapNHits/EcalEndcapNHits.flag',
#  'EcalEndcapNHits/EcalEndcapNHits.g4ID',
#  'EcalEndcapNHits/EcalEndcapNHits.position.x',
#  'EcalEndcapNHits/EcalEndcapNHits.position.y',
#  'EcalEndcapNHits/EcalEndcapNHits.position.z',
#  'EcalEndcapNHits/EcalEndcapNHits.position.t',
#  'EcalEndcapNHits/EcalEndcapNHits.truth.trackID',
#  'EcalEndcapNHits/EcalEndcapNHits.truth.pdgID',
#  'EcalEndcapNHits/EcalEndcapNHits.truth.deposit',
#  'EcalEndcapNHits/EcalEndcapNHits.truth.time',
#  'EcalEndcapNHits/EcalEndcapNHits.truth.length',
#  'EcalEndcapNHits/EcalEndcapNHits.truth.x',
#  'EcalEndcapNHits/EcalEndcapNHits.truth.y',
#  'EcalEndcapNHits/EcalEndcapNHits.truth.z',
#  'EcalEndcapNHits/EcalEndcapNHits.energyDeposit',
#  'HcalHadronEndcapHits',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.cellID',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.flag',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.g4ID',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.position.x',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.position.y',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.position.z',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.position.t',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.truth.trackID',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.truth.pdgID',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.truth.deposit',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.truth.time',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.truth.length',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.truth.x',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.truth.y',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.truth.z',
#  'HcalHadronEndcapHits/HcalHadronEndcapHits.energyDeposit',
#  'HcalElectronEndcapHits',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.cellID',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.flag',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.g4ID',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.position.x',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.position.y',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.position.z',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.position.t',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.truth.trackID',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.truth.pdgID',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.truth.deposit',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.truth.time',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.truth.length',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.truth.x',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.truth.y',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.truth.z',
#  'HcalElectronEndcapHits/HcalElectronEndcapHits.energyDeposit',
#  'ForwardRICHHits',
#  'ForwardRICHHits/ForwardRICHHits.cellID',
#  'ForwardRICHHits/ForwardRICHHits.flag',
#  'ForwardRICHHits/ForwardRICHHits.g4ID',
#  'ForwardRICHHits/ForwardRICHHits.position.x',
#  'ForwardRICHHits/ForwardRICHHits.position.y',
#  'ForwardRICHHits/ForwardRICHHits.position.z',
#  'ForwardRICHHits/ForwardRICHHits.position.t',
#  'ForwardRICHHits/ForwardRICHHits.momentum.x',
#  'ForwardRICHHits/ForwardRICHHits.momentum.y',
#  'ForwardRICHHits/ForwardRICHHits.momentum.z',
#  'ForwardRICHHits/ForwardRICHHits.momentum.t',
#  'ForwardRICHHits/ForwardRICHHits.length',
#  'ForwardRICHHits/ForwardRICHHits.truth.trackID',
#  'ForwardRICHHits/ForwardRICHHits.truth.pdgID',
#  'ForwardRICHHits/ForwardRICHHits.truth.deposit',
#  'ForwardRICHHits/ForwardRICHHits.truth.time',
#  'ForwardRICHHits/ForwardRICHHits.truth.length',
#  'ForwardRICHHits/ForwardRICHHits.truth.x',
#  'ForwardRICHHits/ForwardRICHHits.truth.y',
#  'ForwardRICHHits/ForwardRICHHits.truth.z',
#  'ForwardRICHHits/ForwardRICHHits.energy',
#  'ForwardOffMTrackerHits',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.cellID',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.flag',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.g4ID',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.position.x',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.position.y',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.position.z',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.position.t',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.momentum.x',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.momentum.y',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.momentum.z',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.momentum.t',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.length',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.truth.trackID',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.truth.pdgID',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.truth.deposit',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.truth.time',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.truth.length',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.truth.x',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.truth.y',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.truth.z',
#  'ForwardOffMTrackerHits/ForwardOffMTrackerHits.energyDeposit',
#  'B0TrackerHits',
#  'B0TrackerHits/B0TrackerHits.cellID',
#  'B0TrackerHits/B0TrackerHits.flag',
#  'B0TrackerHits/B0TrackerHits.g4ID',
#  'B0TrackerHits/B0TrackerHits.position.x',
#  'B0TrackerHits/B0TrackerHits.position.y',
#  'B0TrackerHits/B0TrackerHits.position.z',
#  'B0TrackerHits/B0TrackerHits.position.t',
#  'B0TrackerHits/B0TrackerHits.momentum.x',
#  'B0TrackerHits/B0TrackerHits.momentum.y',
#  'B0TrackerHits/B0TrackerHits.momentum.z',
#  'B0TrackerHits/B0TrackerHits.momentum.t',
#  'B0TrackerHits/B0TrackerHits.length',
#  'B0TrackerHits/B0TrackerHits.truth.trackID',
#  'B0TrackerHits/B0TrackerHits.truth.pdgID',
#  'B0TrackerHits/B0TrackerHits.truth.deposit',
#  'B0TrackerHits/B0TrackerHits.truth.time',
#  'B0TrackerHits/B0TrackerHits.truth.length',
#  'B0TrackerHits/B0TrackerHits.truth.x',
#  'B0TrackerHits/B0TrackerHits.truth.y',
#  'B0TrackerHits/B0TrackerHits.truth.z',
#  'B0TrackerHits/B0TrackerHits.energyDeposit',
#  'ForwardRomanPotHits',
#  'ForwardRomanPotHits/ForwardRomanPotHits.cellID',
#  'ForwardRomanPotHits/ForwardRomanPotHits.flag',
#  'ForwardRomanPotHits/ForwardRomanPotHits.g4ID',
#  'ForwardRomanPotHits/ForwardRomanPotHits.position.x',
#  'ForwardRomanPotHits/ForwardRomanPotHits.position.y',
#  'ForwardRomanPotHits/ForwardRomanPotHits.position.z',
#  'ForwardRomanPotHits/ForwardRomanPotHits.position.t',
#  'ForwardRomanPotHits/ForwardRomanPotHits.momentum.x',
#  'ForwardRomanPotHits/ForwardRomanPotHits.momentum.y',
#  'ForwardRomanPotHits/ForwardRomanPotHits.momentum.z',
#  'ForwardRomanPotHits/ForwardRomanPotHits.momentum.t',
#  'ForwardRomanPotHits/ForwardRomanPotHits.length',
#  'ForwardRomanPotHits/ForwardRomanPotHits.truth.trackID',
#  'ForwardRomanPotHits/ForwardRomanPotHits.truth.pdgID',
#  'ForwardRomanPotHits/ForwardRomanPotHits.truth.deposit',
#  'ForwardRomanPotHits/ForwardRomanPotHits.truth.time',
#  'ForwardRomanPotHits/ForwardRomanPotHits.truth.length',
#  'ForwardRomanPotHits/ForwardRomanPotHits.truth.x',
#  'ForwardRomanPotHits/ForwardRomanPotHits.truth.y',
#  'ForwardRomanPotHits/ForwardRomanPotHits.truth.z',
#  'ForwardRomanPotHits/ForwardRomanPotHits.energyDeposit',
#  'ffi_ZDC_ECAL_Hits',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.cellID',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.flag',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.g4ID',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.position.x',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.position.y',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.position.z',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.position.t',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.truth.trackID',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.truth.pdgID',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.truth.deposit',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.truth.time',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.truth.length',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.truth.x',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.truth.y',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.truth.z',
#  'ffi_ZDC_ECAL_Hits/ffi_ZDC_ECAL_Hits.energyDeposit',
#  'ffi_ZDC_HCAL_Hits',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.cellID',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.flag',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.g4ID',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.position.x',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.position.y',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.position.z',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.position.t',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.truth.trackID',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.truth.pdgID',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.truth.deposit',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.truth.time',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.truth.length',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.truth.x',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.truth.y',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.truth.z',
#  'ffi_ZDC_HCAL_Hits/ffi_ZDC_HCAL_Hits.energyDeposit']

# %%
def get_vector(varname='HcalHadronEndcapClusters',energy='energy'):
    E = np.array(ak.to_list(ak_arrays["%s.%s"%(varname,energy)]), dtype="O")
    x = np.array(ak.to_list(ak_arrays["%s.position.x"%varname]), dtype="O")
    y = np.array(ak.to_list(ak_arrays["%s.position.y"%varname]), dtype="O")
    z = np.array(ak.to_list(ak_arrays["%s.position.z"%varname]), dtype="O")
    theta = np.array(ak.to_list(ak_arrays["%s.polar.theta"%varname]), dtype="O")
    phi = np.array(ak.to_list(ak_arrays["%s.polar.phi"%varname]), dtype="O")
    return E,x, y, z, theta, phi

# %%
def get_truth():
    pdgID = np.array(ak.to_list(gen_ak_arrays['mcparticles.pdgID']), dtype="O")
    status = np.array(ak.to_list(gen_ak_arrays['mcparticles.status']), dtype="O")
    genStatus = np.array(ak.to_list(gen_ak_arrays['mcparticles.genStatus']), dtype="O")
    pex = np.array(ak.to_list(gen_ak_arrays['mcparticles.psx']), dtype="O")
    pey = np.array(ak.to_list(gen_ak_arrays['mcparticles.psy']), dtype="O")
    pez = np.array(ak.to_list(gen_ak_arrays['mcparticles.psz']), dtype="O")

    return pdgID,status, genStatus,pex,pey,pez

# %%
E = {}
x = {}
y = {}
z  = {}
theta={}
phi = {}

# %% [markdown]
# ## Get clusters

# %%
for i in ['HcalHadronEndcapClusters','HcalBarrelClusters','EcalEndcapPClusters','EcalEndcapNClusters','EcalBarrelClusters']:
    E[i], x[i], y[i],z[i], theta[i], phi[i]= get_vector("%s"%i,energy='energy')

# %% [markdown]
# ## Get Truth info

# %%
mc = {} 
mc['pdgID'], mc['status'], mc['genStatus'], mc['pex'],mc['pey'], mc['pez']= get_truth()

# %% [markdown]
# ## Loop over events, fill clusters into constituent arrays; run jet clustering

# %%
def find_truth_electron(mc_container):
    ptmax = 0.0
    index_e = -999
    for i in range(len(mc_container['pdgID'])):
        if (mc_container['pdgID'][i]!=11): continue
        px = mc_container['pex'][i]
        py = mc_container['pey'][i]
        pt = np.sqrt(px*px+py*py)
        if(pt>ptmax):
            ptmax = pt
            index_e=i
    return index_e

# %%
def get_kinematics_electron_truth(px,py,pz,beam_energy=18.0):
    electron_E = np.sqrt(px*px+py*py+pz*pz)
    electron_pt = np.sqrt(px*px+py*py)
    electron_theta = np.arccos(pz/electron_E)

    y  = 1 - (electron_E/(2.0*beam_energy))*(1-np.cos(electron_theta))
    Q2 = electron_pt**2/(1-y)
    return Q2, y, electron_E, electron_theta

# %% [markdown]
# ## Loop over events

# %%
evt_ID = np.array([])
gen_evt_Q2 = np.array([])
gen_evt_y = np.array([])

for ievt in range(100):
    constituents = np.array([], dtype=DTYPE_PTEPM)#DTYPE_EP)
    hcal_clusters = {}
    ecal_clusters = {}
    hcal_clusters['E'] = np.concatenate((E['HcalBarrelClusters'][ievt], E['HcalHadronEndcapClusters'][ievt]), axis=0)
    hcal_clusters['phi']= np.concatenate((phi['HcalBarrelClusters'][ievt], phi['HcalHadronEndcapClusters'][ievt]), axis=0)
    hcal_clusters['theta'] = np.concatenate((theta['HcalBarrelClusters'][ievt], theta['HcalHadronEndcapClusters'][ievt]), axis=0)
    ecal_clusters['E'] = np.concatenate((E['EcalEndcapNClusters'][ievt],E['EcalBarrelClusters'][ievt], E['EcalEndcapPClusters'][ievt]), axis=0)
    ecal_clusters['phi'] = np.concatenate((phi['EcalEndcapNClusters'][ievt],phi['EcalBarrelClusters'][ievt], phi['EcalEndcapPClusters'][ievt]), axis=0)
    ecal_clusters['theta'] = np.concatenate((theta['EcalEndcapNClusters'][ievt],theta['EcalBarrelClusters'][ievt], theta['EcalEndcapPClusters'][ievt]), axis=0)
    
    
   
    evt_mc = {}
    evt_mc['pdgID'] = mc['pdgID'][ievt]
    evt_mc['genStatus'] = mc['genStatus'][ievt]
    evt_mc['pex'] = mc['pex'][ievt]
    evt_mc['pey'] = mc['pey'][ievt]
    evt_mc['pez'] = mc['pez'][ievt]
    evt_mc = pd.DataFrame.from_dict(evt_mc)
    evt_mc.eval('E= sqrt(pex*pex + pey*pey + pez*pez) ',inplace=True)
    evt_mc.eval('pt = sqrt(pex*pex + pey*pey)',inplace=True)
    evt_mc.head()
    #Find true electron
    e_truth_index = find_truth_electron(evt_mc)
    #print('Electron truth index ', e_truth_index)
    genQ2, geny, gen_leptonE, gen_leptonTheta = get_kinematics_electron_truth(evt_mc['pex'][e_truth_index],evt_mc['pey'][e_truth_index],evt_mc['pez'][e_truth_index])
    
    gen_evt_Q2 = np.append(gen_evt_Q2,genQ2)
    gen_evt_y = np.append(gen_evt_y,geny)
    evt_ID = np.append(evt_ID,ievt)
    #print('TRUE VALUES OF Q2 = %2.2f , y = %2.2f'%(genQ2,geny))
    #print('TRUE VALUES OF E = %2.2f , theta = %2.2f'%(gen_leptonE,gen_leptonTheta))
  
    #print('#################################')

    
    #Loop over

# %%
df = {}
df['ievt'] = evt_ID
df['gen_Q2'] = gen_evt_Q2
df['gen_y'] = gen_evt_y



df = pd.DataFrame.from_dict(df)

# %%
df.head()
# Out:
#    ievt      gen_Q2     gen_y
# 0   0.0  140.708791  0.949510
# 1   1.0  130.367123  0.011864
# 2   2.0  117.427152  0.196462
# 3   3.0  154.347415  0.891210
# 4   4.0  174.409173  0.515356
